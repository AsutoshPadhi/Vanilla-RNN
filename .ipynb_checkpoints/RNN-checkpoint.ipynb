# %% [markdown]
# # Vanilla RNN Implementation

# %% [markdown]
# ### Imports

# %%
import numpy as np

print("Imported packages successfully")
# Out:
# Imported packages successfully

# %% [markdown]
# ### Basic RNN Cell

# %%
class RNN():
    def __init__(self, hidden_size, vocab_size, h_init):
        
        ''' Hidden State '''
        self.h = h_init
        
        ''' Input Weights '''
        self.W_xh = np.random.randn(hidden_size, vocab_size)*0.01
        
        ''' Weights from previous state '''
        self.W_hh = np.random.randn(hidden_size, hidden_size)*0.01
        
        ''' Output Weights '''
        self.W_hy = np.random.randn(vocab_size, hidden_size)*0.01
        
        ''' Hidden Bias '''
        self.b_h = np.zeros((hidden_size, 1))
        
        ''' Output Bias '''
        self.b_y = np.zeros((vocab_size, 1))
        
        ''' Gradient Parameters '''
        self.d_h_next = np.zeros_like(self.h)
        self.d_W_xh = np.zeros_like(self.W_xh)
        self.d_W_hh = np.zeros_like(self.W_hh)
        self.d_W_hy = np.zeros_like(self.W_hy)
        self.d_b_h = np.zeros_like(self.b_h)
        self.d_b_y = np.zeros_like(self.b_y)
        
    
    def forward(self, x):
        
        ''' Update hidden state '''
        self.h = np.tanh(np.dot(self.W_hh, self.h) + np.dot(self.W_xh, x) + self.b_h)
        
        ''' Compute output vector '''
        y = np.dot(self.W_hy, self.h) + self.b_y
        
        return self.h, y
    
    
    def backward(self, p, h, h_prev, x, target):
        
        d_y = np.copy(p)
        d_y[target] -= 1
        
        self.d_W_hy += np.dot(d_y, h.T)
        
        self.d_b_y += d_y
        
        ''' Backpropogating into h '''
        d_h = np.dot(self.W_hy.T, d_y) + self.d_h_next
        
        ''' Backpropogating through tanh non linearity '''
        d_h_raw = (1 - h*h)*d_h
        
        self.d_b_h += d_h_raw
        
        self.d_W_xh += np.dot(d_h_raw, x.T)
        
        self.d_W_hh += np.dot(d_h_raw, h_prev.T)
        
        self.d_h_next = np.dot(self.W_hh.T, d_h_raw)
        
        return self.d_W_hy, self.d_W_hh, self.d_W_xh, self.d_b_h, self.d_b_y

# %% [markdown]
# ### Read data

# %%
''' Read the text file '''
data = open("shakespere.txt", "r").read()

''' chars is a set of all characters in the text file '''
chars = list(set(data))

data_size, vocab_size = len(data), len(chars)
print("Data size = "+str(data_size)+" , Vocabulary size = "+str(vocab_size))

''' Indexing every character '''
char_to_idx = { ch:i for i,ch in enumerate(chars) }
idx_to_char = { i:ch for i,ch in enumerate(chars) }
# Out:
# Data size = 1115394 , Vocabulary size = 65

# %% [markdown]
# ### Hyperparameters

# %%
''' Size of hidden layers of neurons '''
hidden_size = 100

''' Number of steps to roll the RNN for '''
seq_length = 25

learning_rate = 1e-1

# %% [markdown]
# ### Loss Function

# %%
'''
    inputs is a list of integers containing the indices of characters from input.txt
    targets is a list of integers containing the indices of the next character from input.txt
    h_init is the the initial hidden state
'''
def lossFunction(inputs, targets, h_init):
    
    ''' These are sets containing values at each time period '''
    '''
        x_set : one-hot input at each t
        h_set : hidden state at each t
        y_set : output at each t (set of probabilities for the next character)
        p_set : set of probabilities at each t (normalized)
    '''
    x_set, h_set, y_set, p_set = {}, {}, {}, {}
    
    h_set[-1] = np.copy(h_init)
    loss = 0
    
    
    ''' --------------------------------- Forward Pass --------------------------------- '''
    
    ''' Iterate for every character '''
    for t in range(len(inputs)):
        
        ''' One Hot encoding of the input '''
        x_set[t] = np.zeros((vocab_size, 1))
        x_set[t][inputs[t]] = 1
        
        ''' Forward propogation '''
        h_set[t], y_set[t] = model.forward(x_set[t])
        
        ''' Normalize probability '''
        p_set[t] = np.exp(y_set[t]) / np.sum(np.exp(y_set[t]))
        
        ''' Softmax loss '''
        loss += -np.log(p_set[t][targets[t],0])
    
    
    ''' --------------------------------- Backward Pass --------------------------------- '''
    
    ''' Iterate backwards '''
    for t in reversed(range(len(inputs))):
        ''' Backpropogate '''
        d_W_hy, d_W_hh, d_W_xh, d_b_h, d_b_y = model.backward(p_set[t], h_set[t], h_set[t-1], x_set[t], targets[t])
        
    ''' Clipping to mitigate exploding gradient '''
    for d_param in [d_W_hy, d_W_hh, d_W_xh, d_b_h, d_b_y]:
        np.clip(d_param, -5, 5, out = d_param)
        
    return loss, d_W_hy, d_W_hh, d_W_xh, d_b_h, d_b_y, h_set[len(inputs)-1]

# %% [markdown]
# ### Sampling

# %%
def sample(h, seed_index, n):
    
    ''' Encode as one-hot vector '''
    x = np.zeros((vocab_size,1))
    x[seed_index] = 1
    
    indices = []
    
    for t in range(n):
        h, y = model.forward(x)
        p = np.exp(y) / np.sum(np.exp(y))
        idx = np.random.choice(range(vocab_size), p=p.ravel())
        x = np.zeros((vocab_size, 1))
        x[idx] = 1
        indices.append(idx)
    return indices

# %% [markdown]
# ### Training

# %%
''' Iterative index '''
n = 0

''' Data pointer '''
p = 0

''' Memory variables for Adagrad '''
m_W_xh = np.zeros((hidden_size, vocab_size))
m_W_hh = np.zeros((hidden_size, hidden_size))
m_W_hy = np.zeros((vocab_size, hidden_size))
m_b_h = np.zeros((hidden_size, 1))
m_b_y = np.zeros((vocab_size, 1))

''' Loss at iteration 0 '''
smooth_loss = -np.log(1.0/vocab_size)*seq_length

''' Initialize the RNN class '''
h_init = np.zeros((hidden_size,1))
model = RNN(hidden_size, vocab_size, h_init)

while True:
    
    ''' Take input from left to right, seq_lenth at a time '''
    if p + seq_length + 1 >= len(data) or n == 0: 
        ''' Reset RNN memory '''
        h_init = np.zeros((hidden_size,1))
        ''' Go from the start of the data '''
        p = 0
    
    ''' Pick seq_length number of characters as inputs and targets '''
    inputs = [char_to_idx[ch] for ch in data[p:p+seq_length]]
    targets = [char_to_idx[ch] for ch in data[p+1:p+seq_length+1]]
    
    ''' Sample from the model '''
#     print("\n")
    if n%100 == 0:
        sample_idx = sample(h_init, inputs[0], 200)
        txt = ''.join(idx_to_char[idx] for idx in sample_idx)
        print(txt)
        
    
    ''' Training '''
    loss, d_W_hy, d_W_hh, d_W_xh, d_b_h, d_b_y, h_init = lossFunction(inputs, targets, h_init)
    
    ''' Calculate Loss '''
    smooth_loss = smooth_loss * 0.999 + loss * 0.001
    
    ''' Print status '''
    if n % 100 == 0:
        print("------------------------------------------------------------------------------------------------")
        print("iter "+str(n)+", loss: "+str(smooth_loss))
        
    ''' Parameter updating using Adagrad '''
    for param, dparam, mem in zip([model.W_xh, model.W_hh, model.W_hy, model.b_h, model.b_y], 
                                [d_W_xh, d_W_hh, d_W_hy, d_b_h, d_b_y],
                                [m_W_xh, m_W_hh, m_W_hy, m_b_h, m_b_y]):
        mem += dparam * dparam
        param += -learning_rate * dparam / np.sqrt(mem + 1e-8)
        
    p += seq_length
    n += 1
# Out:
# Qdc&B?W?o,BEpSxuMMKCdPggAAlAxRFWvv?k'R
# m-3ah-B!pd,FaYWrDgAhYNdrphh:aprX&iifzI&rs!RS$&ijrN;jafT$!-WgoMPyPrBQrbT'MHj3YSmzWBOVS3vXg!vXRUbW,VA x';DQOf.NzDyJPiH:$cUg'HZ?bjD&E&M3jibTXsDy
# DNqtBm: fYlK.jVwjG;
# ------------------------------------------------------------------------------------------------
# iter 0, loss: 104.35968043619299
# s,hsihasswrowwsHw
# eawharehswrwswahrwssUrHswsUwhHwaaews wwarsesaaawew
# aahswsawww,Hwr
# s ssrwseaH iHwrrrsws rww
# swsras
# esHhH swa
# sssws
#
# ,awssawaaw
#
# wwear
# h
# ht waw
# whssww
# e  s w r srewHs,sw hwsHwrars rwr
# ------------------------------------------------------------------------------------------------
# iter 100, loss: 116.78326323475925
# h.ooou, .t
# oooioao.lc.v antosouoourrawiw.at....o oaovoiaaoooooooaowonooore.eroutafalrwsiooceooo,Sro.n.e.iloatw.ocwiant
# ca.wooohu.no.ahaoo.tlea..oawo,,eooitwuoonwrhtt.loltruSooi.o.osIhtoooat.taahratee.
# ------------------------------------------------------------------------------------------------
# iter 200, loss: 124.11506034447171
# hsoh
# odsiimisi  sooHCioisoHdsmehroosroismoHmmBooshBiiH
# romteCCsroCHdiooo
# osiohomisoHiu
# h ih
# BoooCsossihoiii
# Cooo
# hhddis
# HhdhBsmsosei
# Cshd
# ot
# osH
# hotooeoHhHsimomHioHoCoHhosBs
# osisrBorroiosoCssosiCherih
# ------------------------------------------------------------------------------------------------
# iter 300, loss: 128.5073797988371
# u sI:IyiiiuuI Iuc uuctiuo mlyiliuniiussmsmuoim:hRIuIiurRiiR,neuuar IuuyduR uynIi s: msmutukouyRu ysRIIyiuutunu,eisforssusuuRsviiaunsRsuo mi IiiuIIiu,rgmibuliI  Im:RuuvdncsoRiccuiR ifRsuibtsRIm onuuuIr
# ------------------------------------------------------------------------------------------------
# iter 400, loss: 130.48732390531248
# siwiisusskikissdnknslnsskmsf
# ss sTdds
# ,u,n ,nsb,lnssi' eibeTTunk nubsr, is ,ibdbs ssTei ssud,nTeo  ssiks nieiek ne ifsoT
# s sokmswiiksmsnTsw us a'ksndiuSibbbsi
# si,kueilnsisi,bksinTdnys,sbdn,okbssbeno,n
# ------------------------------------------------------------------------------------------------
# iter 500, loss: 131.8223247937383
# scyashm e aomNo:   b chh sd  oyh oh h  soh t  w a oa sim insissahs hwcohhoccyi fdianio:h o oc shhhchahhoh   i osbhhio  hyi h cci h  e  ow ayys  smsc: hhiy   n my oemhh y  ofecyh yyn:nohnhoy inytyymyeo
# ------------------------------------------------------------------------------------------------
# iter 600, loss: 132.88645977794576
# Tah a
# keB m i einTon e m a aeaiyu i ,aiw mhhnlea,ahowe   ,mw aa weehi,ea bw eldaak emeuauleae  w  hm   o  ,m
# iT  la ee wa,mwya eh  et,n. alaaBe l,at atT idd, Baa wma ,  en ehlhhieeedi e
# ohder mwea,wTa
# ------------------------------------------------------------------------------------------------
# iter 700, loss: 138.9433889573401
#
# s bmen
# e
# m m m hAb  :m
#
#  mmanbC lmbemede g ymh m hA me -m
# AeemmesC;  m
#  r . eahhe  ae A oeAh
#  ;mme:
# lAerh
# sahhh
#  Hu :egA:a   :e: neA Caeh
#  eg eh
#
#   l ee
# meAg  m lebtbaAr mfes mlbr
# b
# A :blm  uo
#
#
# sm
# ------------------------------------------------------------------------------------------------
# iter 800, loss: 143.40376281950392
# ssisi Ss,ndshS suhsoSss iooese nsncsnSUScseSStSsshdeusvsd S,sesiu ssosSdbsssseIsllseSosnflsU csasdss:nSuh,eelShsobSeTsd nnhtuh SssoS ndl  SedcbavbsSsessosSisSloh nseesdnuehsssSdol Serehsoe dsuSensdSod
# ------------------------------------------------------------------------------------------------
# iter 900, loss: 142.58001949662028
# siicso:ireserhhI-ar sne:Tc:nh :stcinId:
# sos renhsrtne:roearee
# n
# nhh,:hnT  :lsatssaruarsorhceIs:sscIsrsan
# sehrsooe  T:o:ssnTrhhhrIa:Ren hsnuoss e:rahrhr
#
# enehs
#  r:yasoTI:s: ecar:Moanoc
# Masaeeiiu oc Ise
# ------------------------------------------------------------------------------------------------
# iter 1000, loss: 141.62699017889722
# S
# eoo
# souetUsohhthoph
# heySA p puuhcAoarsla
# hooprteproeoStlsS-ouStrhs
# gu
# rthahuSA
# pnp  ua
# too yoooSrtarcnlso yro
# lovSroeusdyueahlAu orrUytlAt
# uhe r
#   ophhuhS
#  e hc hooro   vprhatohA uthyusb
# hecs uheotA
# ------------------------------------------------------------------------------------------------
# iter 1100, loss: 139.35702497846327
#  dnn,mcrewoioio I
# 'iamto
# eniionoocdIe bm
# tomu  mgnmsu
# os   nd
# o  I
#  ni
# noucolbmoeueeisumdeeos
#
# uCscoc, uo nooC,oCooooe
# s
# dre
# rstrdr ao
# gtotonoormoi,s
# eooeecineom
# so
# oegoe
# getesIrnuiorcsooasons
# ioer
#
# ------------------------------------------------------------------------------------------------
# iter 1200, loss: 138.19910560350587
# -CeCsfgkUp aCUUdadaU Um m   ,CodCthUo c
# Uo
# MaeU skUCsy- iaiC e
# m
# arg dUy ee
#  s m
# hU:eUf iUembUC
#
# e
#   goCMyamCMckccU MmM- M aseUgyeUd
# a Uoodf ldha,aUptdMhe aUCi C aUUaeme
# hamfgMCe r ne
# dbaCfskordeyd,lM
# ------------------------------------------------------------------------------------------------
# iter 1300, loss: 135.53968880330925
#  sheu
# hpsmkpoee
# ,pei
#  o
# o
# to,ne wuhuThM
#  i odIu
# am,o
# o noe,ood,oak mTne h hn T
# dusmnmdoeem e,
# toMe a oeeT
# baydum,Mo,m onr ,,cose essmToh ooe e
# suoeou oh mn mneeoeolntou
#
# nndh s
# ttrIoosT
# eom
# u
# utes
# ------------------------------------------------------------------------------------------------
# iter 1400, loss: 136.06089572539355
# e  vg vrvsnushwohn ranolImmgIu iehd Ivenf uvheuvd tnhdIveps Inrtaeuheelngunhnv aS unetvI thtgnn wevmgenhrwhefhaeI herrvft.vlemun eodnv,ervdgeluo,ruo SdInng ,tgnvuvevhuulhnenl inlhtl v gm on v r uUvweg
# ------------------------------------------------------------------------------------------------
# iter 1500, loss: 134.9566212549854
# .chn Iwt
# Ui;S;w  er MM tupnaiUe;kU
# i iIUnM;Urc; lIu;wprtn; UUat Ms
#
# pe wtmwmmt;;cMcotno MnM   knhIo n  p.nuhvUh
# .Smh
# IIMMa; ohMwrrt:yos oM,ectaM;
# el;aMe rooie;or i hiogI;skw nIwkItSI;w;;ie.u.ti ItUUM;
# ------------------------------------------------------------------------------------------------
# iter 1600, loss: 133.44999275340822
# nnnhto  Tnthao oeess   o nl  lfon otom meihCnrtan,lnpen  nkns  tononuotee os, eoee  ete alete o,se,n  ut
# o ee eoln
# oioo,.htCee .ne,aw  nounh onf tliiCo etutennneoo to.tndslnmnAo entih
# . eetsnlhnroeo
# ------------------------------------------------------------------------------------------------
# iter 1700, loss: 132.25662781212668
# ruuuws
#
#  utr
# :wgrruugg:
# ru urul
#
#
# reiu:s
# sr:l
# grae:wu
# u:wig :
#
#
# grwrqheW
#
#  U: h
# i:r mhba mhrr ugu s
#  wqrtU q
# rhr:
#
#
# rw : m
#
# a'hgogr
#
# nrt
# u n
#  w:s ri gruw nilwr:yr rn
# wnMugr
# iui
#
#   Tei
#
# :w r
#  g heq
# ------------------------------------------------------------------------------------------------
# iter 1800, loss: 130.91487542589198
# itk  eosvaa u
# u
# oiInveono  iivu: e sCct ev  e:si,hoto I,   v  Sv n,veiest a f suea rShoe,oocausnseIhI
# ena u  s  yoS
# ahIeS I ogoSo ohe
# sa s Ia
# ro esC ss  gu :svut , v viers  iI,t B
# rs
# eovIsooiev
# or
# ------------------------------------------------------------------------------------------------
# iter 1900, loss: 129.63294322580256
# a veehkbeepp kc kkbkevs rd   tcrhCh kiehpe pk C t phpe'hvvd ththth  u  the,hpeb  egderatee p    t he r 'e ae lb  eploe
# h e krcsr ee e eevv lh  ebe tr ehC  e,'h lkeCLpdhdevee ehaarhhe e  lredhl    eree
# ------------------------------------------------------------------------------------------------
# iter 2000, loss: 127.90724117426022
# eetcete
# hhtheceshste
# and icyetfyhct mtttaetyfmc
# deevdohtdiehtt
# y teerehWeesR
# d yaehye asbfeeahdtndic
# eorhhWa heioiaWslmtlty aWn
# emyne meReaithWsedatth
# a e
# ft mahatntmit
# emfnetWhhmpn
# nneieylh nedtehmbe
# ------------------------------------------------------------------------------------------------
# iter 2100, loss: 127.40091566708055
# wreeebi
# sne'r edsoekondttetaooo t,Ueeo odoew,iteo e..pdoi n hpoo:dp'o pnvntoeoipoedr eweoaetop haf h nl,ne uaouetkyop fnpdpdeeaee eeut.o'a oneo oknenfn fnydrce dofsmidefooodac s deewn ntitfonaftofetee
# ------------------------------------------------------------------------------------------------
# iter 2200, loss: 127.99607281027617
# ckh  dA
#
# smkto muA
# co maykeymhhiF hsle''mdkky heym nm u'd er y nAeahu  ym oh  shu
# Adsaounhtokm
# hFdsmuh c
# mck ekAtodkomk'y  mkm
# m:yen''h'i ooyht c haa ammsnrm mom tcc
# me'yisi,'hhtd mu ' mu''es
# 'f''h
#
# ------------------------------------------------------------------------------------------------
# iter 2300, loss: 127.35156001580783
# ot a t ite eyhst f: n  Oh  i  osrtvehoretiehvat gtahi  neetUeefuo vegoivee eseiaeeL:et  ttesiOftrs  Oatim esihs veessi
#  ete  tesaseyisevLiertissoia  oihftstt
# Lt esssL i f ts v ief eoitmtahtno  esatosr
# ------------------------------------------------------------------------------------------------
# iter 2400, loss: 126.22373629543134
# leUacuhe sh
# ca hz nzchz,'Us,omh
# d
# asawhnhhoicoifneeiUzuneew hn z e  auzuDmchidew ,zwsT: wic
#  oDaa aes'
# zhEaheiU hn DDhwhz  szU
# hwshi  hz hiiea hhcauahUUCC dnowewi.ehfiiasUsieUiweh w a n ssiCUih
# izSuFU
# ------------------------------------------------------------------------------------------------
# iter 2500, loss: 124.85512174744107
# , Uennde Unw :llsen wwn rore,k ok  wermt:ne.hI w.Utwnr:swnCeA Anlce  :nlkla nw eosiwUtr atls  Ueo.sCt eanroh :sharwAeh m w e  rsA nshkl,ewetUAotkilm sUIekfrki   o slknwU:nIe
#  sI esdaInlwr nke wI rA AI
# ------------------------------------------------------------------------------------------------
# iter 2600, loss: 122.75295674297678
# e
#  Add-  SAh '-
# r hrvdh-t
# hIehth Ai e
# u
#
#
# lh
# toon oloAslSd  tAr
#  Tifod Crmhtuh
# ShhrAAAo
# ct'e lwrho
#
# T rru ce S Sy
# a
# deo-l-
# TieoIssAsA  ceo
# goTrhoA AAeA
# ru AtC-SlcctoAAd eolAe dhiASesLd-itoCiloo odA'A
# ------------------------------------------------------------------------------------------------
# iter 2700, loss: 121.5321507891502
#
# BCNN
# nolno i owemNoI h'
#  NNl toB' ,
#  'hlNN
# s
# tBd hBtw
#  w t'
# Cm'itd 'ptR ain,'
# to'h eNh'ins'N s'uphp
# o' mdiN '
# ' f
# I'w
# thso
# Roi' Ntanwns, o sa hniohaUt
#  ,hoh moo
# p m'tshofNt
# onwNaw  ' ' NNNRb
# NI th
# ------------------------------------------------------------------------------------------------
# iter 2800, loss: 120.20260717008743
#  auae,.e L ao ohu:rr e:ep, g.us. thehelr,s sorlv geg.t  :g um,ftta
# t sgm ii
#
# h
#  nigtg er g eg
# 'ottg mu em , se,
# e
# mt F.L Lhrp
# ur :uu g trge.:m.ug ,otgmr  .f
# g  elFeovrtom.:  i
#   ,,vaier
# nt
# L v:ym
# ------------------------------------------------------------------------------------------------
# iter 2900, loss: 119.98171912868276
#  ldetttett  hwhhCrtl  CtebetcebtM w   wewtl nlewiptt e wtwtthneheerehttMwl lt btebt aael eel w b,lh aht: tplt,ehnheht i ee aweeaeetwBehCetnee  nen nerC  itwb  awtti  dria wbn w  t tltte hC   een  nr t
# ------------------------------------------------------------------------------------------------
# iter 3000, loss: 118.00499472174246
# tsodealm NyhanNrn N  h oplet cdns  sNNB m  stmWU hI , mnCut mlaoc esto r o leh mcNenttemN M  leciedhoee nE e oln,im  uNm yl   hnn ooI en nomcmao lsnah  n m  oNe
# C  i,Ns sEhsNhlm,  saheoos  eces nd oh
# ------------------------------------------------------------------------------------------------
# iter 3100, loss: 117.89692293218862
#  e Le.w.hla runslos bn
# s
# rhoeeew,t,eoais:nisDetztSotl unona taed.oS nehsssts
# ueieEososnEo,sslthoh o  dooSnlaIwistth ,
# ssBlltssEapswss
# otUaaota,st
# rtzeiteSu
# tets ooyosL
# oioa,e
# tossDSosies t aehti ehaii
# ------------------------------------------------------------------------------------------------
# iter 3200, loss: 117.74773711409571
# ahbeennnhdhtnetobetteaibmoetmeooimdhetremoalwtbrnbaebtte,bol eartra tbo a pbe Shehr,
# ,tt,te  abhnc tt tsonraereee en intlt,neeoneeeooo hSebaelana
# aeeeroanbe ehdorotnIeolhd t ennSattndtett eobeb
# eneeeo
# ------------------------------------------------------------------------------------------------
# iter 3300, loss: 116.89334781279555
# neetaeEI ntI nBarrn yrI,sarouIa snss? et?r?Iwnanrreetcee ele Iooa feobsea wbIaenaLfn osn sterroenate  rIrao eSou,na  InaIerEo?raee   goy neUcf rtrn tea?etcts SetnI?st clhoacheEanIaerIe
# IceIorxIcsccn x
# ------------------------------------------------------------------------------------------------
# iter 3400, loss: 116.05796787729496
# aIeel,.tt
# eiillgint,I o.
#  h..m u leelIIg nmyIbnl  ilIemA..i. eattt i
# oelie e,llVai,enpmi
# aiytiiIuia irt.e.liiiOasiI..tlfll.. eail
# e
# iel.,.nas.sleiso. le.m . lIlnoe e.
# eelllaalr.limitn asn
# imir . e
# ife
# ------------------------------------------------------------------------------------------------
# iter 3500, loss: 114.95926658453078
# i hn eoo::ohftee:Csoedewc estmsodt.nhhtAdto  o :s: eCAmttht:t tnou t nctO:emheend shOwtod woth h:c'erd hs od:onitll sonh  h ien  hth :BneWtth slLhnno etsehhaehOtsis
#  lmththe :htO yenh  :teahleescme.t
# ------------------------------------------------------------------------------------------------
# iter 3600, loss: 113.89958205569755
# rai
# er
# h; tlr i  avi
# varnrar. dsrsUhart fnvrrcv ;rvu ,ner wotacUatnstaaa ;thia asvaihlraeo oa
#  ,riUotsc eav sarnasaa eec
#
# eas hivdaororasae  ,u Esessetndv,f ld
# d ataaen  fie aarevett srta
# chraa ;eac
# ------------------------------------------------------------------------------------------------
# iter 3700, loss: 113.74345299039815
# ampamue
# OeOf
# e eROemofsmeek,,
#
# ee,be nefemdea
# rnsE,aif mmeeC
# srleaOeaee
# e,fsak e
# soenerrNoeea
# eT
# eaeaMedCuaennoaminiri,leeaOe,,,iEkeEbereerenrC,l
# rcnptfreeaio aebOln
# eekal
# n,eene,
# d,aap,amne tnl Ta
# e
# ------------------------------------------------------------------------------------------------
# iter 3800, loss: 113.64354524501957
# rsNoptuoduese,NplIr r,ey h eI mosnoNanNee.IoIaraluuu eu ryIamnNt roInr,s oe,oanorenel as:snlyIueNruo, sruseN.srNoeeu,uhuIusrieei eupIutes,isrI eNu
# s. oe.tuLloNoeet lNnyhrrou..wrh,i No!re.s otmrraeoos,
# ------------------------------------------------------------------------------------------------
# iter 3900, loss: 112.79032890895844
# IhNhy Indor dpououN p   N,
# IN
#   hUosI::pItyy ys,slil s: aIopN d ytro y hyItupaalulsy  o
# lpyhoI
#  ppp
# NIa,suIy  y  a:ayop:e: eaoho
# y:Ng yo
#  h:uusnyu ydhtOhalmu
# soptI  NIps NIu Npf
#  u:sI
# '  oU u
# oyl
# ------------------------------------------------------------------------------------------------
# iter 4000, loss: 112.31609154114918
# w-a opd  wapoitddp dvh
#  osd -o  pil eBstnih  pd ad
# iapi stao hman.hdwhomes  pi
# sas m .h p npipapt n ahoh on,iBo
#  :Bm:wbdaloiBaha
# cB l
#   h i naa   a  ah i  Ba o -nipBioaeel:rn bom  pi atoipp pahi
#  sma
# ------------------------------------------------------------------------------------------------
# iter 4100, loss: 111.51241027726509
# nanihelnyla  ae y nrati snnt Hee nn taii,eeairtiart :  lvit tna  el,h i alia,eta  i t ane etiiettena lteaei ttthi t  rant e ttntr innen e nie,i nh,tne  iae    in niaaee nnIier RiRhti   nhtat  est,h
# ------------------------------------------------------------------------------------------------
# iter 4200, loss: 110.46194439098285
# i tCtpow  d a iAhh
# d
# n awdA atUe tenmdt rhe dwl    htwsalnh n
#   ps
# ehe?o o?d aUI h:thmeo w h
# sa heiio n tiU sdivi omhpomn tm mdvi  t  v m  If
# nhthwhm UhnC m
# r ote
# fa   Upm
#
# hI
#  hiTn
#
# hb hwh nRpp pshm
# ------------------------------------------------------------------------------------------------
# iter 4300, loss: 109.77276360931099
# AaioIa  a h IdonIvh s h ,ahsronwaA mnmmhcit
# rn.s radIe,IaInihsne'aro yotyo  erttIt wa nn hfin Aaeanhiu nAhhy   t
#  AAthmsamtbAbssh,nydaid
# ynorcooistuii'Ahc rrit,shasrsttnAntatthias nttlrysainhe ohaiIn
# ------------------------------------------------------------------------------------------------
# iter 4400, loss: 109.4284571074545
# ar
# in'mIvmarAvrvmooe:
# It s iteInwerSlSennesrrn' rr:i
# htrrsnvirSenirfI
# olohsa,eiaeivS,iv
# r
# insrshnatee o
# vm muovrirmwaR'rm ,evnhrisnhvs
# rmrrrrurnamed
# ntaimrAoronr
# rmwrs tn
# :a lal
# noinnvm!rnmn
# t
# hIieirn
# ------------------------------------------------------------------------------------------------
# iter 4500, loss: 108.38867548957103
# uShohtaa e a audlaonulFh-n to l
# f Wao  o s hoduto lu o raeulnao hoWeFto cntSo,aS lettnraaotmtalcrieao ;te c ote
# too o tilrogt roet s
# tae sndtnnga rlltaeislntma   tle tduaao
#  e:Fnna o ttt da :rrn diev
# ------------------------------------------------------------------------------------------------
# iter 4600, loss: 106.91276672425278
# tteiysthInahtpiIataap  httB tyt p htnli oir tanwi
# eiltir
# Chis
# rt ntathinmBeattn
# wpatarshtuehtror  ihoBw
# c  aiteletipoocralnotloa: anttlwrtsiet
# ftSst SwuttBia tgntIp tttiwntohalsnithnw  tslcatrrwI hnc
# ------------------------------------------------------------------------------------------------
# iter 4700, loss: 108.08196557627876
# LoCcCde; te
# tsJneersewl  Cea
#  Cct.ewCktUCaNAtsC
#
# droM Jss:Cd:e  .Itos
# dwotosesatr huU
# e-oysMde -yeegaMvt enCJt s-Inteu h,s J
# cCsiC  dnsuuh escnses
# at.eaJ ens
# sI-h UeNos:Jueulhc
# J cuwsne J
# eee-hry efc
# ------------------------------------------------------------------------------------------------
# iter 4800, loss: 109.02386241407784
#    ona    unrbwrioiUuuupm mrM.au?mr
# yur
# eO  holy
# arfMsr
# dgmeitni
#
# enirri
# rol dtu
#  rdhudr
#
# r
# t rtdMren d brw
# ? uedaod
# diul?tu
#  miiui
# oWriinii
# dp
# dnr mial
# iwpr rve
# aoiirdhin
# dSs r.mmrp f.
# ,
# uW?w r
# ------------------------------------------------------------------------------------------------
# iter 4900, loss: 109.07151309007101
# s
#
#    sIobh
# heot
# tdsl  seqss lai ssyho a stsns
#  eeau e hitAohl sseA hRs  sthslob
# tsstt cntoP e  aoc s tehehFtmteet  e Aeete tsleth
# s aAw ts
# osn A
# ss noIeW AylAc    hhe Alo ortsset  eo
# oF
# kene shr
# ------------------------------------------------------------------------------------------------
# iter 5000, loss: 108.33565797739827
# rhrrvs So ea rlihte,ouls lnrhwper  xtidM rMhoee'ooe udr wnnuehnd  eeeeef,unUawd  mm dwa
# me eewma,a
# st:hefa MwUm e efne,wM w rn zwremeo mgeuoeeah aefor etnUnpUhrrmrse  r raU xdae a  lMa od,ieaeUuUerpme
# ------------------------------------------------------------------------------------------------
# iter 5100, loss: 107.81559204762094
# w lcouUcbwo clu Icc i:elR:yeriieufsslO :tlic.ff RrRT
#   tUisU
#  a
# ol   ln ueloec tiTNlOfe t   nr ry i nce fNUotlUi   escs  elo :cibees tus eUOo t
# iiNrlrRfc Usa es'aswfue iNhnwls u    n eU,ROli lscSom
# ------------------------------------------------------------------------------------------------
# iter 5200, loss: 107.19758132903979
#  f l  lioorf siotleah
# aiusnasa:ntnelemmln eIeeen niop oittamb, noeb t oI maSsorob anhooosm eo i:Sonncasalaauo epInl simns inc:aennbtftoo nhoaalaNtntniyoefvaoas: ,n  tnoomf yt ntetiefkit,hteoi tortaos
#
# ------------------------------------------------------------------------------------------------
# iter 5300, loss: 105.94435273436197
# reSaedoe erb deeg r t ttt - ,tshhepNCehhh h?ehhhh he h
#  ho SIbhr ?t
# aseoh sen-  i
# afetlo appleghfs o IaStgd hthas fhhph tf ptSb  iht? i tgsoehdi e  s-ttssihh ottae dm -dt isp edNhhRo dhheesia  d aah:a
# ------------------------------------------------------------------------------------------------
# iter 5400, loss: 105.50457358011064
#  o roea o itccv Ie claoaukornlv wkrHka:clne woeR
#   k lwar  :s
#  :
# kro oRko!fs cco: tssoowH  ooafpe  ock oe
#   te :corossocaFvoF
# pe kowkows e s wnkios ocs:ypF
#  wrnse roaiO ok
# co yisn w  riRava c oaos ch
# ------------------------------------------------------------------------------------------------
# iter 5500, loss: 105.56064711958497
# ba  otne
#  sr oasang otenndaWessCeot me   p WCeCo  tuaasii
# soi W i nhgtudCe eA
# r   i ninr eC eieshnoen ynWg   eWedohWn n t t ee  is  a hst eiho
# uAyslhe ey   n oa r aeeoer  aethtar   Westn s
# naannss
# e
# ------------------------------------------------------------------------------------------------
# iter 5600, loss: 105.01822446284405
# ' ooeur oooeehsaioinkoeuoim' lhoooe don ouw  eokor ocrouw  roledk s  i esko  w'rnusl ort
# hur us
# eeasu
# r'louehed osoe,tdte
# d'ooetsw,od uhw ns
# eoroo dt kkwdaslremen
# eke oeseld'r nwn o 'at
# 'rtloe
# ar'hdko
# ------------------------------------------------------------------------------------------------
# iter 5700, loss: 104.56080154511078
# f:i nkaA :tid'bd':N stlsb:ssastifdn.f
# iiiS.iiahtodh.i:is:sldnsiAsd sl taeat.in ft sisNissh  id.h bsd dIs Sls
# nns mEe dbnibsb.l b Ne. soei b oediid ii dEnlia :osoa e.leN tesodi:fsdadiishtNo:A  iaisai.d
# ------------------------------------------------------------------------------------------------
# iter 5800, loss: 104.55056128526701
#  wea
# eA e ioeeidht'Iheiei ,hen  o  ,i a'..   t.ae t eIi hni N. eIheoUt, rn  r ret h  ai
# e'm ri Iimmseam If ntAe'ee bt Ane sia eimSewnevo inwihtewmnt oe  h ettelt,eImhnin n  ,ddihi raaokrtl am tn  ataa
# ------------------------------------------------------------------------------------------------
# iter 5900, loss: 103.79307921519747
# huase llwshaddrhe sleesssrFh e ga  n hegAh: ae nrhto hmu,gFo ehog uF.l,uu'aale  iaehiet,e
# manehgfionic memhu he rahe aheoemhseegslurelnhheAp  eng ylleeoaulfyFehlhehaeog g   uh aha  h.ulroesaeen e ueuh
# ------------------------------------------------------------------------------------------------
# iter 6000, loss: 102.98745922099405
#   lo.mmCime.,bn
# rme  .ftenefl: n io
# fmitm:
#  rssnIllglm.uectrsmmaSmti
# sfIirttthaniofsmHfB,r ftmeiteUtlhtMfsla sgimisu
# rhs
# i.l e.,iiao .msmutmbtm   Mgaaaaoatammt,i
# u becnse  M iet.mfDteill   e
# .sgnsg
# ------------------------------------------------------------------------------------------------
# iter 6100, loss: 103.46150041625069
# drdy te'P pisr  d eira   h pmetseP eOa anxfa e, pdrd sO  sf a dnroxiedp knad. rratahano adpnUhoa  eaueahesuo trsddad ktorr.u  fmtoeenaamolrbtPw rr   dnutdacdasenaeah roeemafsemm lePadord disardOm eO r
# ------------------------------------------------------------------------------------------------
# iter 6200, loss: 103.56718043516759
#  D e a
#  mteeesermreHwtmneomeaelLer h wao L new Do hogeto   nheru wemm nt  wdneremo siadawrnnehaeeoo
# oo  yhr
# m   n nnIn
# ty
#
# ot
#  aorto hutae mwt m
# tthennwoho srt
# n
# i
# hnehtiw noyh ny s e eose
#
# mom w
# ------------------------------------------------------------------------------------------------
# iter 6300, loss: 103.34939459294448
# Oh
# O.tanuhaUuotps htlmhn aUemhhh
# t
# naersutdH. ncosacuSAUcr
# huaa h Urieao ia hl
# lUn rhUg
# lHaEmoahhae
# cpua, uI asuuh oteaaaoo mtsueh urcrsrUae rtoaus H m tspursIoahua
# oluyscayEaahsehorolhta  t at
#   en
# ------------------------------------------------------------------------------------------------
# iter 6400, loss: 105.8095942892838
# dodo wtadn e dheedtetymhshsr te t. s e,aaosd rsn bta ,dlkbs h dl dr,vd,ra o  aw, lodhedheaaWbtroe,,r d taerbt,df  rd ,tbrfarrttros,urbrhkdrnro ahn dftaorrsrrtwseopa.fodotlsr,otthtdas  dbeedt seshttetb
# ------------------------------------------------------------------------------------------------
# iter 6500, loss: 106.1472947585547
# toe
# nasnoo Nbwto
# o m o
# nsukhsou
# u
# tw t
# ivo t
# suSs nunn
# w
# nn
#
# oilSScieo
# owuSSo
# nu
# SLoLbSu
# io
# vw
#  S tt d  ts twwontoso pulew
# Swthyseoao
# LeenodiSwL
#  wbo
# Ne, n snpv
# oowSuuhLkvwov
# rwvlssnOipSeoS s
# o lS
# ------------------------------------------------------------------------------------------------
# iter 6600, loss: 106.45204407374173
# /home/asutosh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:37: RuntimeWarning: divide by zero encountered in log
# orfnruvu
# tsretaisoft s
# ec Yaest.acd.trtt ktsnrrauostf
# teLsr.et lu yn neta hautlonftlufutssrtn. nOetkesn:s:llEattran ehcsstNeACnLn ucsYnokuYn
# f
#  n souLuslEtafadat  Ar uaLen utaellcLft:rl.c
# eotnfctwetr
# ------------------------------------------------------------------------------------------------
# iter 6700, loss: inf
# e  es sch yrtm,
# rnhvrsoe iyro
# yh  yrdl soa  macy ,nhhcoowrreoo,r hc
#
#
# n e,eonr
# t enarmu yroprcs,dd o onm Tpasorai fear T eio
#  cno,,
#     acey tor t o,oh rlyeeo; Ra
#  he TY yeo'rirtiwoe  uoi
# u
# nc,nrhcoo
# ------------------------------------------------------------------------------------------------
# iter 6800, loss: inf
#  r,o  SaobNRu  eOewa ynraavttS, lhl r souiOhhat
# rugiR  hht eaRgiOoRSuuso ug hubOe On  rh reaWhmaaS Eah OLNR agmOa a
# ThrRohRaR iNha WbnrthaW ,aR .S?
# is aorhsu,aw rW REeaSr ?EaSSab?hE r  ucb u lbtwO ar
# ------------------------------------------------------------------------------------------------
# iter 6900, loss: inf
# oTeyeTr f n
#
#  oaamor woIotm ura e yNB
# rr:rurn y
#  btmo NnkTyiyEIt oNTd: l Ioa reiaouNoohTlorrounTT Tryoroa :lraoTiaNrbio
# rrykaIaa  oeryymlob
# yI, lsoycIT Nalu
#  arouay
# obmsI
# r y EiesnT kytmleEootoeosyNr
# ------------------------------------------------------------------------------------------------
# iter 7000, loss: inf
# WdnvM,drtemeyio  lHenlov r:ntnyakklcfa y  wnwd
# ed gkrd rrohhkt WarWelw
# eowetH ore,nnnkse
# ereeryrnns ey Emgwa Ew wawhewmrrauH WrraenvenEhHn rnwWor? a  k oEe yWlnnyr
# m ef  c nw
#
#  an r rrka E
# rrahr
# y
# ------------------------------------------------------------------------------------------------
# iter 7100, loss: inf
# dyduy rvirhh tfeeithrf ie f, ; a;f e
# crrenf frdno w: iasynfhs nyfsisnvend
# ot.,ra
#  n  dn i hnmAaaIiUMaarfcond,t rio thyen vfefEe eed shMfnyt,rf,d
#  mhnadyynbrf
# shjefcief dednnhdueienned n h EtyirAa f
# ------------------------------------------------------------------------------------------------
# iter 7200, loss: inf
# rts
# t  ydseltlklSaliytty inS,twkhSftsduiuotiecCoetftitv hthtrtoTSiEso ul ?etinyRs:set le dtthpd te lnt  ysovn nl ocny tkyfwif?lhneuuosihodaiske
# scr ito
# dntnd yRpllcRsrtatS ytlnsCntokh,lodeotntsu
# t
# aft
# ------------------------------------------------------------------------------------------------
# iter 7300, loss: inf
# r
# ddtT
#
# Ta
# aaE aE! o  h
#  EtaeupwphvbrntsAmbTThvr y f
# ,a byTbt
# o :fs: mttEta
# bedodte tpEdt h dhstbldlo!:det T b
#  d
#  h!EE!!
# f   glt!Tr
#  tT:hvE tsebaTao!l the atyc  EhE
# f,
# nomsfbmeydph  ooT
#  y
# dubTh
# ------------------------------------------------------------------------------------------------
# iter 7400, loss: inf
# srgbiethete  Sl ntoe-etgd cfsolnAtreG;rteetece mtElcIbnoehtokeo hielttEemsetnCelelcoieatc
# StbtsstrGeudmnybtouesonyon tdnt,ese a ttg  e
#  te
# w yctsG UeRseUeneeSagcnAnhhsgetAIkomcoAhtt
# ero tG
#
# t nb Utkct
# ------------------------------------------------------------------------------------------------
# iter 7500, loss: inf
# rnevke
# yvt  edlCtos tddeldrdi
# al v
# o ldddNu,o,yodrrrdcndpdeeprosvsd.tlsNdt  rn
# dla iuiILlou
# drlv Irveee,r Ohomses dtw:wtl roedr r  ro oyssdnsal seN CeelLder e v
# lrddminaod ssvrdovedso r o r
# lrLs roos
# ------------------------------------------------------------------------------------------------
# iter 7600, loss: inf
# teifiYt,druM iYtoitcMb,te ec
# td ksi sahM tkdinoidaumhhf dto
# ibMot iurmfssMeye aolt hntudadsoh
#
# euthkCsahhnof k is m tIIuos   buhisooaaIkpu iasfutahitoMt
# efmo
# ylsy dmysm httem h o wbvoo,idhhgdyhyk  maM
# ------------------------------------------------------------------------------------------------
# iter 7700, loss: inf
# seed,ted anntae sn cui ianc it   iihdseennAht sec isti
# k ehlnT ontR  sksolIeomseRaeissitrnmRh nBtit iittteRa etmedellmB tn stinsnin ndnm rrll lb n  nnisek t ctienoiku t ntein  cli mimdeihlh ee ieulo.r
# ------------------------------------------------------------------------------------------------
# iter 7800, loss: inf
# u wnh n ktoewhg,eu obdtbYlItiifsta
# ,ue,rhbi
# ieYuei  deaf e  vp
#  Ftt enogl
# woite kY
# Ie,bohdtaiaihiulIrwkhit,tit,rha,ehtbh a nu hbue
#  etahaistafwe t.rFehetbivtdethw?
# t eh wrter
# hweyravbbIhwt
#  tF,btf
# w
# ------------------------------------------------------------------------------------------------
# iter 7900, loss: inf
# oo fioE os
# dneourdto e,osdteuod drLaeusu doed d:du,o etdo dercr r'huordhro   y oNo oiLeRrdruibd rN f f,teubrdrbo
#  olof  Ru sNs st LRdurrts oe iao ehE oerlhr rrds so
# of r u' osttoress htThubtu,rlr rbbr
# ------------------------------------------------------------------------------------------------
# iter 8000, loss: inf
# raTonl.rl
# n m s
# rm  irn ydrr huaronyl
# m teo
# eltLsntdes
# nma yll
# nuael
# y  nmnn tn l,i shiesn in  r Vo ui   slm  sN  lBnn plo  i m t urs nr,ur
# to esRa yu iyr . lynaaruaT  is el uoGne si.m,ueee
#  R
# N cnyl
# ------------------------------------------------------------------------------------------------
# iter 8100, loss: inf
# ;rnr
# wibV m;Dd hunE.
#  tgoVDrfshm,s;eoi . kRth.,t;lsDhus  d
# ,lhv r Vtdlulhrhn ;hA
#  ,horWmeeeIm  hDl m Vbe td vye;aime frfeD ttumRawfm
# bR, l R;ihtfw;  ni
# e
# Efm eatD ttw teEs yiDmmmhh
# twm,m
# ri ate ofioD
# ------------------------------------------------------------------------------------------------
# iter 8200, loss: inf
#  OkEknEkwrdheOOaiCrEsdh:Crk dcCnoO t  eObnehklurIddCEn ndnrecs hderteuEtRdhed
#
# o d;r kdreud rreeit Fn de goyF iO,csihrhyo oore tOshnteC rdelhe osnEd
# rrwd tw;:e O h id
# hrktodikrrttEtr
#  e d hrir
# de:toie
# ------------------------------------------------------------------------------------------------
# iter 8300, loss: inf
# a,N
# rrr
#
# nneor
# fcmtu
# ooro ni UoM.
# ytU
#
# t mnruiasmr em
# u
# trouad,.ao.daoo t' rip e
#
# aoc,era u  Uf ies
# rUa !olNoo
#
# hUdha nhreU  oeo ua
# pao.Iuo,rn Namrmoo
# c,eyl,udHf
#
# g
# U
# rpfrs
# .r r!farmoMduUunrN
#
# ------------------------------------------------------------------------------------------------
# iter 8400, loss: inf
# hadhmocy chb mtfclu-t abtutn
# amaf emlg oe u Cr
# eu drrn c rddvubdneamuyttgebaemmme beuatahIen saor  uA ag a teCha,hlhduCugtai mtryh
#
# moucTpe .eundnHdoaoad  tab
# -ra
# mh
# nmhu denhan u huntagmt atmdhuif  e
# ------------------------------------------------------------------------------------------------
# iter 8500, loss: inf
# klsvSTn, o o mmy ibo yedtohoTro t mievavovteoroSndu vr  rt av  l! oeu ts; .cy m;
#  heSt domr!eerbSe
#  thteed sr;h
#  c gySenpeasave SvfSt tooet.eehet ede;t;v ;ognt ue;o oteer
#  enu oyevi c
# vl  ;So mc
#
# ------------------------------------------------------------------------------------------------
# iter 8600, loss: inf
# o hsel:ieo
# dl eeT t o t i.seThk.hgndm.oeM   dFan   it e dnmgg h det  gStdl o  d :o .  shweet lr.nei tjps h tg. CoU tiii:gdattg s  .ns Sm ielimC  edrgN h.posi nhhledhiemi ith di l ln.ehonetshrn .hit:
#
# ------------------------------------------------------------------------------------------------
# iter 8700, loss: inf
# lhsemaah eca cc stdoahw aodeeanrGdtm  Be kcOstn  au laali m shei  d
#  riaq cn ,seshee.kel a,e .ceda e e,eootneGw t ua.aHneydrialiedua s,r:aehlt satue wed waYdnccnce  nYaGr
# dwddtwl ss
# ec   decaasOBrinOe
# ------------------------------------------------------------------------------------------------
# iter 8800, loss: inf
#
#  e ,olI  t eoy
# ,tR o c
# oao oaly  f
# yeorwtwDD twe
# n elIthcmeo
# w eR ealylslD s
# eeLeme y a
#
#
# d eeIte  is  re
# nlwt AyBDo   r sAI
#  fa
# o eytoltle wlna R   wt C
#   ame ya wlrnsItntaaooiy bia dlT eoldl e hl
# ------------------------------------------------------------------------------------------------
# iter 8900, loss: inf
# gsAiIttteTliYelamto Lll:
# tl
# eA tIu wuaolintuoiesa aeoes
# ntosfonApllmonceBAuantfnmeass suAdilnnlme o yso hi tl lottteIuAseph r otsteeldtpuaRiiyo
# aII:tu inleaIty mnsottuos ouoYtn meItoneu lsa ntoo t dft
# ------------------------------------------------------------------------------------------------
# iter 9000, loss: inf
# ehgsIg  oa mekts
# h tWa  l feeo Wkwttttwikclhrc eeRie  yEdttl  s G
# yhtcutrr DnthI,ldrlov  heoEroyftowGaRGyMkk,fh okWwoWKvcGoyR ewWD
#  v  o v hfio e hvR,cUthsek NkoolIas,E,:kh iy,oWto
# cwyhy udllWhNonSfis
# ------------------------------------------------------------------------------------------------
# iter 9100, loss: inf
# tteqkiRvoCnutniItoku Rinftz
# tRu hvttt.tERo iIdboEiznkteinihrprvyetra atycttCAtu?ttr?E?BeEplknWtAokGnR
# En i opuioCwII,aGRt MopmtkhAo,io
# l?itGonon?t't?a:omte .,dhtEtAu,noaEEri atto uGaT hoEt?MoiThet aTo
# ------------------------------------------------------------------------------------------------
# iter 9200, loss: inf
# EeLnoopeL
#
# o enpd neS upetoun n   IeLdteIilegnee l e en o nre psL nttuSu
# Iag nlnG.scdclg' i O mtGitoe
# gtnessM  sLte
#  he  e
#
# AtI.Gonge ut:segeoLntepseuoewt hsAe
# e.GL.lu   Mrn
#  soGtGt.h
#  tts  nge
# ------------------------------------------------------------------------------------------------
# iter 9300, loss: inf
# . ., leatnli mnoolv i andlol.dllelakvntio ra
#  k   e .alnn ,hn r, a ollsn,v..l
# ok, r.t:npii
#   o, al  no. oa rv o
# , te,er,lco
# heo.,a eN o
# nuov,rwloot! ce  ot:'ek,i noIGul  , ch  ,dlloe.oeo...,o   eodvn
# ------------------------------------------------------------------------------------------------
# iter 9400, loss: inf
#  t eegIntoltoio .hnt oogIo  oWadt lhahdpvie
#
# odv   orHiikN de... lk oh:tu oSeou  m tuiloogG ho n tsaihloehged  nggheao coghieWn iylidh oti Igndod litI  oHG
# yildInivsong
#
# er:nro Gnitle Ahia     iedh k
# ------------------------------------------------------------------------------------------------
# iter 9500, loss: inf
# eieIla olmtmvN ny G YetHiNkel iyeeu cegoudl
# icea, t
#  wu
# lnmia
# lik
# ,e,lcmlnYoI trmnNc
# om em aPno oaaY mtado eepAoIgm .led iaNN oeTm kt
# e   k,ei
# e
#
#  ngm
# otiacu i uoc
# elmau Ism,
# iynmnYHfeS mo y,  ,k
# ------------------------------------------------------------------------------------------------
# iter 9600, loss: inf
# hmRbiamte,tatiro: t b tt   re  toosiwSawwmmbwo yf HsiarSIdtRhe  TvTtttn SkhaTmSiovhw htStmmRSI
# oTuaw fbpt  Rt e tav p mltwrmt Owfhommkahao fSitaRt bi,oTiS,i ,T n,,hteotoT tt rlGa-iitv Skn ,
# hwaovmsioy
# ------------------------------------------------------------------------------------------------
# iter 9700, loss: inf
#  aa eMdT oU Erat  av    dGLvR a aivG:n ady kttGv h Ol  hheretn SHuv  elaaTAwd eisnOe te hte Oon, UtOarGd dLekaII hs Et vaoiv  de:  a SsL ei ridayas C radOdT  MCO:dn d LOdnT  ynnOet  nTa  ena  r d a dn
# ------------------------------------------------------------------------------------------------
# iter 9800, loss: inf
# llttn al l lal
# u E ndleleh w
# ht lnyalnw:e,
# aifEhEtn:  Esu'eilta:te hUoEea
# noea,r  wn h trWi tura-ai  ,s:wiW,ysoWrysgr'h letnchteehrnee
# Elr emhs dseebWh tiieyiieh  chna: i  lwhrE s eberl:s galfaitwiedi
# ------------------------------------------------------------------------------------------------
# iter 9900, loss: inf
#   nto t i  r o  disre  eB ic danr  ss , trn
# nrfensr ;rrsn  ferne ecad  r,r Tr   st  sea eieia  're n nnrirBe  r tiNena s  ncinBthee'   ii y,p itirr nw ty oss y r eaei,iden  trepceoc iTi Tn ee rirciB
# ------------------------------------------------------------------------------------------------
# iter 10000, loss: inf
# o
# neogmnWlhw  p.nesanoopenmgo
# rr,mCs,o,,nm
# eono gw,.eCnei e,e inerd hnt . hy,nnn sUoKy,Co
# yghspsynC,nshaeE id iCmikwr
# r ,;odu h;epemhdm
#
# m:e inwdwtm
#
# erndmidd; s.mEmn;a et,
#  ld ddcplii.m kvewm;
# CEhC
# ------------------------------------------------------------------------------------------------
# iter 10100, loss: inf
#  rharoeemor o tsTavsc,rlrloYh sihGA roe atoiAht oloT,ssmlrneYesollh.e eooc  wsels.iflIlAosloite iGsuh mhlsrrnrlr YfYosyrrahhlL GfAhnoGtoho LTotsTs eronrosu ot m  ytsAsAn iyac-,ho
# h lol l
# i  roeioio ou
# ------------------------------------------------------------------------------------------------
# iter 10200, loss: inf
# wrportebsWdewnfresaacAarbnaauhera lhodiet ure sp
# awT  te wba ie erAwTyibaneiwdoeea reer hebtienatnooa aae
# ybtTtotd oeateance  uws eogneedd.Breeoegar do  atnfnhcre hc u neeeAootAiudeeeaoioohdeoyTrd
# a
# ------------------------------------------------------------------------------------------------
# iter 10300, loss: inf
# f on hdaH
# yAtl
# ef
# os lmgiO glbfbhlb
#  ay
#  dk ars eslaodl rmn h
# las drihyffaehla lmrlaeSHirgdyHyrl
# cmladyhlid lta  edredypuBllla irinlaa
# S ihmtsrryldNeh
#
# ibrmr  ll ol
# tin lilInfleiiyrrmssHocnlt
# ysy lt
# ------------------------------------------------------------------------------------------------
# iter 10400, loss: inf
# esmelEpiaohhher mEthihrtr
# tweerccre ',Niitb hcth,cbeed: merei  EttrettB  rgp,lipid, e iT hpd
# io thHAcAoa
# hew
# Y gEherbralutoreca z hrtdpdHuyiieo, irrhoabiehsr,drnbep hdec
# e hehd rdtr eohoTiie o ploe o
# ------------------------------------------------------------------------------------------------
# iter 10500, loss: inf
# Ass sAaloaa
# onteslwrnopnleuo l-nt-odlUowkwisIAdsLi Iwon,wl- stN dalYL:idAIasau
# Ita,,al:eQns,NktoieruN -fworI,rse oo ssyossiaAlo l NaawuosArt-brrms  r,A nw  nl:ipnsvtlYa,eenuweu Tr-nten:nuAl:su,LnHAs-l
# ------------------------------------------------------------------------------------------------
# iter 10600, loss: inf
# HI    gut   TaHitI saTKIn hti
# mH a sm fnao  fdno
# u,I  riT toy,aiie,: T rTH n  Iu maH ro aniho  tH  ttoerm T  nNa,tb s ,uT Cit, ewe,Rm
# mrmine y
# onIso oKianHrata n T eT nt T N,  tdiIia i:lIaH   wein ns
# ------------------------------------------------------------------------------------------------
# iter 10700, loss: inf
# N vor  :cdlo lrpIt w IrlB
#  iclpeN
# Ia:l dBAe to mcal
#  uv
# eR o, nd
# I:RIr otnc
# tsIaAilccq
# Ri io,lI
# r
#
# Ic Iqdca ,tlcneAunodI In a
# BIloa
#  lcd
# lAnoouptmh ooomANe
# dceIamd
# oc  c It Kdioom mannmceeR
# lIhi  o
# ------------------------------------------------------------------------------------------------
# iter 10800, loss: inf
#   tedhsoa oo ralosetloieaonht.nor l rni myweede?hi
# afTeogi ila  idnshloataemtendeysslkIion yn  hl lomsonl
# l
# hoenh sIeTyh
# ulrgl ihoelxarmomatoateltwn Rsb enaoyio
# enie,lfhejeyeoassremo asneyiarewlmtdr
# ------------------------------------------------------------------------------------------------
# iter 10900, loss: inf
# wmohu e Rt tv, s urh r rauea ocuRhulc,whno ftiu a ,onf
#  ottcfEfas
#  neeehfy,luor   oenneluil
# EednAtswa
# onf
# rseatAhhlar  athebeidaet  i  uaei fs  seh e
# E!tetsnnno oGeraoee oe vwss'ro,rl
# N hd erh tg nc
# ------------------------------------------------------------------------------------------------
# iter 11000, loss: inf
# b brenbC etfoweh
# roteheneeinnh
# hsr tttnae n   rybeoetbo btef tbhGbb
# vn bbeh,,oetaiTihhecbe
# c e
# l eebbbbaanefhtn  nenpD nbaya bc ewpbEh iT
# imbdb hro
# ubannTfemfa ehuia aonn oT,rn dhnpt te,edwnoan  nae,
# ------------------------------------------------------------------------------------------------
# iter 11100, loss: inf
# yh eIE tutwoon r Nt,trIrk
# r ,tvcehh,e   rba Hra,   etroh rgucdICchcee  h
# , Uer guramRaratlu age  oBi,t,hatEQutt,,dgngaEa, e aagaEs t
#   hIeg, atvQa h,s Dyretnune
# n   a  ou  h,IEg kecHahaenahsdvatrrhrar
# ------------------------------------------------------------------------------------------------
# iter 11200, loss: inf
# o Gleo nhasdssedw,Inslnsdeicon ph Fvwy irYiinyrtps iHd
# e hnou.pbolYsyn  is hleisohtesyoh swluf dhoyhl yeionnlo ptshawrrstewrnyt  FNh ioiHeSdi cpCc
#  eo sclo In llesi oyaili i ette.opinoIrerYts eu  hrh
# ------------------------------------------------------------------------------------------------
# iter 11300, loss: inf
#  e
# tL
# dvadyUtbtdthtmvtnhugdbmac
# eBhtIhdmmn
# b
# gc
# eatheIcnBh
#
# e
#  gtvtitmLmILNL igh
# t
# ul
# dhb Hdodenyv fr  ecIrtht
# gsgCn r,
# tmIbe
# l
#
#
#  teht,Lc
#
# e
# tlcfa
# cr M Cneheivti tRltrtM
# u
# mc lh bcnie
# tcdegef doedrn
# ------------------------------------------------------------------------------------------------
# iter 11400, loss: inf
# iteec p cvgebh h
# sAuaunecoat Es ov
# ; eestyeh t
# poaeunh
# honee tyee
#
# uup   uluolIrnt;eBucsoanve g I
#  ulT,sceoev hhdv
# hc d aT ctocgaepoafIu
# u
# hgvotcleuclIvIpflleDpRelaIhncen
# eohv eu
#
# gu hsumehuslyhluycu
# ------------------------------------------------------------------------------------------------
# iter 11500, loss: inf
#
# acshiab tNtthi t ih th GnI,iiwd  vi'h hhoheynlrt B hlTw
#
# he n
# n
# :htBn,uai:Ai   L nhE, n ebe
# h
#
# ld h  ieheatnhbi
# wAss
# o    hn Itic .  ucry
# yi mAgla t,Aneh:B Aii
# tht th ilaahAHb
# aieNi i a wrst eni
# ------------------------------------------------------------------------------------------------
# iter 11600, loss: inf
# u ei s;nethiiumie e-   f  tinh eh mwat  ieqw adamwrwwrDee'
# yrawco c i iriRcdyoi are at ieareos'ttr eecada; o  eede
#  rUeew q a'tno tttHrrewonrrwwmi eetew Aa  eawGt o ar e'heIK itwte t
#  ei BeiAieRia iry
# ------------------------------------------------------------------------------------------------
# iter 11700, loss: inf
# Ntlohim
# denhn
# riioeoolEo
#
# nr not bE
# cooP
# l
# C. oot.il s
# t lgLolfmNfoohlgiefndhse
# yu
# w
# o,lItm iNociRl ntliocl iw
# eN wmgticoR
# ,nllrNtooIDafoul lh:o,nl
# m
# if
# ltr egl huoulntt Nou o
# IuavitNoht Il,rlsf
# euc
# ------------------------------------------------------------------------------------------------
# iter 11800, loss: inf
# fEIRnslI:vvl.onefav l oIllRslIdcluvl:yvn vt,ei ltueHs:ophElIRoiCo.Ep l?fv.f:IyroCshe eosgv,ieAi oere: v
#  ::mow loe,drlIho
# mtouduranII:oIelvCuyt,lAl vanlItr
# fmwi: MICvotr a
#  E,:,vr
# As,CEI , ovNoar s lt
# ------------------------------------------------------------------------------------------------
# iter 11900, loss: inf
# lheRossw yhe eKep
# thd deneRK
# mkO eapnebetnteff
# kositlui;nOarirre
# erbnSethrbhoiyr  otedS ftuaby !kore
# ttSrehslah, ssleeremmr. nierm merRetrefedraser ah
# rfotwoedylods lo; kaeteSresrhereYsaehw  Rheiete
# ------------------------------------------------------------------------------------------------
# iter 12000, loss: inf
# oori hh s   s?eioh,c,ed spfee tarwf  ycmo, c wroh rdyos rhh,ylof
# scserr-o-
# Gae ai oso l,ryshtsc wesoc owsrst ,twol,  ,e tyhaG njbs-cerasosonph  eh -eit suicwprs.yohe
#  easse' Weyfsfihnlhsw'iebwe eh
# es
# ------------------------------------------------------------------------------------------------
# iter 12100, loss: inf
# dtaboaosrooue
# hoa'gm
# lmof
# obulCis
#
# bo
# tmntltssso  tb wS
# teuleodonhobst lu g 'seCu  i
# anig smisnsfel shu
# dltmol,trltthieofrsn ea  tsul out
# Rgo tshrl
# huC
#
# oiiolg
#
# tlnasnmrst atlni'ag odu'h'Cspwgttvute
# ------------------------------------------------------------------------------------------------
# iter 12200, loss: inf
# gohoeawhedido bsytouoegcnhed ifid gfuhinsrb-duoerbeuatRorfishuduul nothldwim.LmedLcrseiE irsfuedewL L tsttRfgsrutuhnIdeoso
# d,sdsferoei ucioloconudllulosne fwdoiislysteucpd  ridfel t
#  Ei.lrf r iffs
#  Ko
# ------------------------------------------------------------------------------------------------
# iter 12300, loss: inf
# HIaGaGH  hIt enTmcrchH efeehhhGertcNr ha
#  ? n lnavnTmtc
# ta domlPoccTH
# m ebua hd?ns I H gnRfta Nhm e d
# oGaeelerhoPio  tro;eHafe aa f fmp or
#
# md
#
# ltt  o  vh a tiN eewnl
# tr ?reoesfN oa lvPyi
# yfauNGna
# ------------------------------------------------------------------------------------------------
# iter 12400, loss: inf
#  a at  eika
# td eu Oh
# y d,mrhl lamh,-hl  huatedmesoaOi h-t   aroyt  Mc emr r  t;Dwee, rrfeui
# thh Odeerse
#  , stagen  hteh tadyd ,i serho eaohTMteareeldls lurhdu rds ;,eu,eehh  ha shtfamalhth herdddmod
# ------------------------------------------------------------------------------------------------
# iter 12500, loss: inf
# CcIhnefeapIsh
# NlAiRhI Dnhcm lmiuanIfioD dNuoR
# aNnNoafCDt  te sCpeio uyIslani Sa yfhap ,ol R.g,peImnfeIuholuoL taIiieon eDiiopIph aoushhui s Gaic sloKnRoeacf y so ofNenCouniDyner a dl ifCnhNCmIyon  u g
# ------------------------------------------------------------------------------------------------
# iter 12600, loss: inf
# hhemWom Gsueh use unog l lullgyctorp
# opGahpioarmne lr ,tu  mhohdeo,
# e  el!sseeruouw orh
# emmcW
# s ehGh h y ttt e ouo
# le
# oeA  e,l ooro
#
#
#  nshu  udTh uismGhlau AeedrnlphdeGoouh p lpr erh ea'Wuheoour tae
# ------------------------------------------------------------------------------------------------
# iter 12700, loss: inf
# nndabf m amfalfldhesulma lu FTdoei M
# lafwhiad udn  obdeefnTmhivanrnuh nablooa oi itnynfi afionlh fnbn
# ltr oahige aeT  oasi tt vMfomolstnTe ns iti
#  nhhneanlco  r   niBd
#  dmvfovfsl etbvrle i liemnh tlhi
# ------------------------------------------------------------------------------------------------
# iter 12800, loss: inf
# trgue,henh oudrrae,r  OosyuYoh,ihl rI eesvtder ,ooisoye gBeyabidye id
# r
# wodYrrb ee,red
# e ,  eeogo,ioel ,reYodlrRymdfordeoO,sfDsbas oy ryyie
# Toa iRo
# razd
# doadi !orgru erraoeseelaaemb,rirli,s eigayejn
# ------------------------------------------------------------------------------------------------
# iter 12900, loss: inf
# schsr tmidsrlm d
# :d.TmoiaIauvvoDipmms
# ems ntoaa isasfct yr
#  mhs c m;mHemedlt Aos  n d aItasmywsmG y t d ntssAstdN ee m   tsenmddeaoi ke:hmx :eiaf hf atmvbta lterimsmtmGtskheeu;sisvctahaer : tsDDio.sD
# ------------------------------------------------------------------------------------------------
# iter 13000, loss: inf
# oalat c u,id,,cd bbftl dc 'mst  n ina,tiaodolle o m bta
# ne frida d  h?bs
#  e,t  mec o  u mhn
# ysas holimoc  lna at ln; aBlts m toes  sdcbe oh lbhe?a emBama mi ?bhue,trmtnert otimsda m,stClaca  om  .  a
# ------------------------------------------------------------------------------------------------
# iter 13100, loss: inf
# oYD ,ytsEdfree:l:EGvovI  iEatat
# tDonah,t gss t,o,roeuy
# d fnnitIa admar. Ennota,trhptYrryDfEine Doo YyEyefE t
# reytls
# t oastahs wk
# eveY
# ga
# d
# dtta,amfhhEaEty fendnou.ae ttrtmohmy,
# wInp
# tno
# oltfa,ntDt
# h
# ------------------------------------------------------------------------------------------------
# iter 13200, loss: inf
# n  feeeollokaphve fnsHohleniiNwHteetkf ondgeeseS  nhtlkiHeht  Hg hrHbkftlhgtapgo?tnneHresNte  euo e Ht  a ishn
# gfifl
# HptynaeinttgngatodsnetH G eo'kFH rIn tfOnyv n  eu;s rdkftoHfwuot
#  dntdtGo   g yltHs
# ------------------------------------------------------------------------------------------------
# iter 13300, loss: inf
# tshrHD dGt httadnagaa rtreIanaenhrs edLfn ia
# dsrtdDh iarat h  it SriurfeLe shhrg rs o,efYMsrr rhtr ttmbaetrtftsIcihf isnHtdsr fl uoLiaas iRtreraLihet Hs siuiu b d bsi
# ooeeRm wHnHseirbcOraa f hi T rskD
# ------------------------------------------------------------------------------------------------
# iter 13400, loss: inf
# tthbtt
# tc dIm Isoy: rcthwIsl ss  l h
#  sytndei ntoeeaeteyyIaaeOtnb eggmmtIpoahe
#  yet
# ac:lhlo oereetdotm
# Id
# Ibhhl ooontlooee eemgaIteuo
# yrbue
# utarlesa
# twa  hbg thtncmwneyI ohaeayel.s, aTtIu
# eIe
# a ct
# ls
# ------------------------------------------------------------------------------------------------
# iter 13500, loss: inf
# lu;hdy mGiIGow otb leluhoms ujMo;intrwniodl uio c r  hoho tenoci M t ; :w cw nefyttoneGwao oomry
# idGmo  oci;nsotlwornoon
# M tdeleuo uud osc em m sInrano estnn g;;
# ro  haonm rewuroudd IoltGmj a  nueehou
# ------------------------------------------------------------------------------------------------
# iter 13600, loss: inf
#  n s e ac doryncuupissern  ttuemsesihe
# eti d ecs   s h hihwecUhvesh nhlhnoGUsygmhtdsiee ise ssh iere siU  ngciootocscniciesgxrsWoodioeroreayepsui rocWidsteceehUe soetW K rto eAiseisemetcnx hnthnschso
# ------------------------------------------------------------------------------------------------
# iter 13700, loss: inf
#  soh atimtooihtaitihRrihlamimlt iBaoH:etdr hd tha  shunmmn
# t DltRra nsaaemiVe  isoMinu umpMHf i s  as i f rniRsiifhnidB nBlur dmnioh Vuh enretiIggnh trhitsie hemRinnth arhHfhuin,iriReuionHdeis mi ouhn
# ------------------------------------------------------------------------------------------------
# iter 13800, loss: inf
# aait :
# e
# dte;ichduoioCRd  ai saoouptomk,otladuwtoui TRteaNdoNiau  stnaaS:dkeOgsedlapC O:RetN s ah,imi
# sio  iooms,oHhooi umd
# ketm:nomeiH'
# eine ,Tilga g:muo d
#   gtuu.oeheog ;Eolrido NS ssiswsskyphmo kOO
# ------------------------------------------------------------------------------------------------
# iter 13900, loss: inf
# E  eatmWW olnahgh!eem nWn inttimnaaww owuedm
# enueaHa
# iai
# mogdshotesrmgnklo
# t
#  omrsm!
# cfoc d gem ntldsd
# anghoe t msmgaioWwnmgntstewnde
# dT
# dp
# mdoo
# ag
#
# ft
# i
# gonaktthocNflefebeisatnhedncci wTtnWnic
# logm
# ------------------------------------------------------------------------------------------------
# iter 14000, loss: inf
# una yvesrapeasravfrstGmeoeeTt,,dibisyh oy'seos,eytntl,s' dhdKmesyd r esdnhalsft
# yssu  fra,sTasms saou uteotsahnlhn alsr bmnhers  IeadyKh,t aeelwauobhshhsanoerttvGyryaesunersem vaamromygaarrsbes rear d
# ------------------------------------------------------------------------------------------------
# iter 14100, loss: inf
# ht,aiiloYc  oisbdincei de
#   io tfenflvatridn ossigh  ngd cmmbnsgbwd nnanhohdw lpurho
#    adoaebww,swnnwi fpbrhthl luivautbinn t ,hid nssse hits sostcms
# slegonhb.is iotbcc onnnw gchlw u o iicctlwnt etd
# ------------------------------------------------------------------------------------------------
# iter 14200, loss: inf
#  WK h oDtdlalfubefamlooRt
# LyloOnaiofo  o sFTtThdtl hsT rhhdvd wWsfAF; t .i  oBon :o T  m.a hdwhb:uyaLT. hBAhnlst tTBHeaR yt deiirofasti.d
# lt Kiddod  iy Gaih   hK Bhtdar;:Aoosa.vhsanmNfsrT,;s
# esrTaso:
# ------------------------------------------------------------------------------------------------
# iter 14300, loss: inf
# eao,icte bchisn abt hhhlht ey dn seeoWtasxeo mfithy naooN o .
# or aree,r   tro toetkhsnsirxrgnePdhihat nh
# ehtotNuootn  Ph ti otle i u PnhhhoA.,No thmn libd m noee l d  UhPTu,  hm,eebnbheTofnihhttmtio e
# ------------------------------------------------------------------------------------------------
# iter 14400, loss: inf
# wt'sav.p 'attsv'trueh rlrv
# n kl'as soasihew e rO'Rereoer  hRpvephaeIhreg.ra Fo o o 'opgI'w
# smia r.hlmlot hwvphhp'h
#  'hh .htr 'r' hj sf
# huh ' 'a
# reI.hpepeo thonms  m hh poehcec hks se:hrhes avssasharh
# ------------------------------------------------------------------------------------------------
# iter 14500, loss: inf
#   sitsdp
# t  tt n oho
# e lhtAw   a
#  p ad oe oyt Qnott t  ,eAyhym auinl  noc oonvwsoowts  ad
# oy  d: atp ntno ai wrdispy Wsu l s
# yrhnh sw heovh sn:tseln p tsnA dH oo
# nos
#  o rp. ts ndhtdlo t o,iytyni.t
# ...
# ------------------------------------------------------------------------------------------------
# iter 601100, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 601200, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 601300, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 601400, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 601500, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 601600, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 601700, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 601800, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 601900, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 602000, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 602100, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 602200, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 602300, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 602400, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 602500, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 602600, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 602700, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 602800, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 602900, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 603000, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 603100, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 603200, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 603300, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 603400, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 603500, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 603600, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 603700, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 603800, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 603900, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 604000, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 604100, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 604200, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 604300, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 604400, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 604500, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 604600, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 604700, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 604800, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 604900, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 605000, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 605100, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 605200, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 605300, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 605400, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 605500, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 605600, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 605700, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 605800, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 605900, loss: nan
# ffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
# ------------------------------------------------------------------------------------------------
# iter 606000, loss: nan
